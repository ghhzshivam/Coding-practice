# %% [markdown]
# <a href="https://cognitiveclass.ai"><img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0101EN-SkillsNetwork/images/IDSN-logo.png" width="400"> </a>
#
# # Regression Models with Keras
#
# Estimated time needed: **45** mins

# %% [markdown]
# ## Introduction

# %% [markdown]
# As we discussed in the videos, despite the popularity of more powerful libraries such as PyToch and TensorFlow, they are not easy to use and have a steep learning curve. So, for people who are just starting to learn deep learning, there is no better library to use other than the Keras library.
#
# Keras is a high-level API for building deep learning models. It has gained favor for its ease of use and syntactic simplicity facilitating fast development. As you will see in this lab and the other labs in this course, building a very complex deep learning network can be achieved with Keras with only few lines of code. You will appreciate Keras even more, once you learn how to build deep models using PyTorch and TensorFlow in the other courses.
#
# So, in this lab, you will learn how to use the Keras library to build a regression model.

# %% [markdown]
# ## Objectives for this Notebook
# * How to use the Keras library to build a regression model
# * Download and clean the data set
# * Build a neural network
# * Train and test the network

# %% [markdown]
# <h2>Table of Contents</h2>
#
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 4>
# 1. <a href="#Download-and-Clean-the-Data-Set">Download and Clean the Data Set</a><br>
# 2. <a href="#Import-Keras-Packages">Import Keras Packages</a><br>
# 3. <a href="#Build-a-Neural-Network">Build a Neural Network</a><br>
# 4. <a href="#Train-and-Test-the-Network">Train and Test the Network</a><br>
#
# </font>
# </div>

# %% [markdown]
# Let's start by importing the <em>pandas</em> and the Numpy libraries.

# %%
# All Libraries required for this lab are listed below. 

# !pip install numpy==2.0.2
# !pip install pandas==2.2.2
# !pip install tensorflow_cpu==2.18.0
# Out:
# Requirement already satisfied: numpy==2.0.2 in /opt/conda/lib/python3.12/site-packages (2.0.2)
# Collecting pandas==2.2.2
#   Downloading pandas-2.2.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from pandas==2.2.2) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas==2.2.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas==2.2.2) (2024.2)
# Collecting tzdata>=2022.7 (from pandas==2.2.2)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas==2.2.2) (1.17.0)
# Downloading pandas-2.2.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 130.8 MB/s eta 0:00:00
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: tzdata, pandas
# Successfully installed pandas-2.2.2 tzdata-2025.2
# Collecting tensorflow_cpu==2.18.0
#   Downloading tensorflow_cpu-2.18.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting absl-py>=1.0.0 (from tensorflow_cpu==2.18.0)
#   Downloading absl_py-2.3.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting astunparse>=1.6.0 (from tensorflow_cpu==2.18.0)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow_cpu==2.18.0)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow_cpu==2.18.0)
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow_cpu==2.18.0)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow_cpu==2.18.0)
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow_cpu==2.18.0)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (24.2)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 (from tensorflow_cpu==2.18.0)
#   Downloading protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (2.32.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (75.8.0)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow_cpu==2.18.0)
#   Downloading termcolor-3.1.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (4.12.2)
# Collecting wrapt>=1.11.0 (from tensorflow_cpu==2.18.0)
#   Downloading wrapt-1.17.2-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow_cpu==2.18.0)
#   Downloading grpcio-1.73.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting tensorboard<2.19,>=2.18 (from tensorflow_cpu==2.18.0)
#   Downloading tensorboard-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting keras>=3.5.0 (from tensorflow_cpu==2.18.0)
#   Downloading keras-3.10.0-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (2.0.2)
# Collecting h5py>=3.11.0 (from tensorflow_cpu==2.18.0)
#   Downloading h5py-3.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Collecting ml-dtypes<0.5.0,>=0.4.0 (from tensorflow_cpu==2.18.0)
#   Downloading ml_dtypes-0.4.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow_cpu==2.18.0) (0.45.1)
# Collecting rich (from keras>=3.5.0->tensorflow_cpu==2.18.0)
#   Downloading rich-14.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.5.0->tensorflow_cpu==2.18.0)
#   Downloading namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.5.0->tensorflow_cpu==2.18.0)
#   Downloading optree-0.16.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (30 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow_cpu==2.18.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow_cpu==2.18.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow_cpu==2.18.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow_cpu==2.18.0) (2024.12.14)
# Collecting markdown>=2.6.8 (from tensorboard<2.19,>=2.18->tensorflow_cpu==2.18.0)
#   Downloading markdown-3.8-py3-none-any.whl.metadata (5.1 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.19,>=2.18->tensorflow_cpu==2.18.0)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.19,>=2.18->tensorflow_cpu==2.18.0)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow_cpu==2.18.0) (3.0.2)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.5.0->tensorflow_cpu==2.18.0)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow_cpu==2.18.0) (2.19.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow_cpu==2.18.0)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading tensorflow_cpu-2.18.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (230.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 230.3/230.3 MB 48.4 MB/s eta 0:00:0000:0100:01
# Downloading absl_py-2.3.0-py3-none-any.whl (135 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading grpcio-1.73.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 126.5 MB/s eta 0:00:00
# Downloading h5py-3.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 56.8 MB/s eta 0:00:00
# Downloading keras-3.10.0-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 54.3 MB/s eta 0:00:00
# Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 48.1 MB/s eta 0:00:00:00:01
# Downloading ml_dtypes-0.4.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 58.6 MB/s eta 0:00:00
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
# Downloading tensorboard-2.18.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 53.2 MB/s eta 0:00:00
# Downloading termcolor-3.1.0-py3-none-any.whl (7.7 kB)
# Downloading wrapt-1.17.2-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (89 kB)
# Downloading markdown-3.8-py3-none-any.whl (106 kB)
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 56.0 MB/s eta 0:00:00
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading namex-0.1.0-py3-none-any.whl (5.9 kB)
# Downloading optree-0.16.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (412 kB)
# Downloading rich-14.0.0-py3-none-any.whl (243 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, werkzeug, termcolor, tensorboard-data-server, protobuf, optree, opt-einsum, ml-dtypes, mdurl, markdown, h5py, grpcio, google-pasta, gast, astunparse, absl-py, tensorboard, markdown-it-py, rich, keras, tensorflow_cpu
# Successfully installed absl-py-2.3.0 astunparse-1.6.3 flatbuffers-25.2.10 gast-0.6.0 google-pasta-0.2.0 grpcio-1.73.0 h5py-3.14.0 keras-3.10.0 libclang-18.1.1 markdown-3.8 markdown-it-py-3.0.0 mdurl-0.1.2 ml-dtypes-0.4.1 namex-0.1.0 opt-einsum-3.4.0 optree-0.16.0 protobuf-5.29.5 rich-14.0.0 tensorboard-2.18.0 tensorboard-data-server-0.7.2 tensorflow_cpu-2.18.0 termcolor-3.1.0 werkzeug-3.1.3 wrapt-1.17.2

# %% [markdown]
# #### To use Keras, you will also need to install a backend framework – such as TensorFlow.
#
# If you install TensorFlow 2.16 or above, it will install Keras by default.
#
# We are using the CPU version of tensorflow since we are dealing with smaller datasets.
# You may install the GPU version of tensorflow on your machine to accelarate the processing of larger datasets

# %% [markdown]
# #### Suppress the tensorflow warning messages
# We use the following code to  suppress the warning messages due to use of CPU architechture for tensoflow.
#
# You may want to **comment out** these lines if you are using the GPU architechture

# %%
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
import pandas as pd
import numpy as np
import keras

import warnings
warnings.simplefilter('ignore', FutureWarning)

# %% [markdown]
# We will be playing around with the same dataset that we used in the videos.
#
# <strong>The dataset is about the compressive strength of different samples of concrete based on the volumes of the different ingredients that were used to make them. Ingredients include:</strong>
#
# * Cement
# * Blast furnace slag
# * Fly ash
# * Water
# * Superplasticizer
# * Coarse aggregate
# * Fine aggregate

# %% [markdown]
# ## Download and Clean the Data Set

# %% [markdown]
# Let's download the data and read it into a <em>pandas</em> dataframe.

# %%
filepath='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv'
concrete_data = pd.read_csv(filepath)

concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# So the first concrete sample has 540 cubic meter of cement, 0 cubic meter of blast furnace slag, 0 cubic meter of fly ash, 162 cubic meter of water, 2.5 cubic meter of superplaticizer, 1040 cubic meter of coarse aggregate, 676 cubic meter of fine aggregate. Such a concrete mix which is 28 days old, has a compressive strength of 79.99 MPa.

# %% [markdown]
# #### Let's check how many data points we have

# %%
concrete_data.shape
# Out:
# (1030, 9)

# %% [markdown]
# So, there are approximately 1000 samples to train our model on. Because of the few samples, we have to be careful not to overfit the training data.

# %% [markdown]
# Let's check the dataset for any missing values.

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# The data looks very clean and is ready to be used to build our model.

# %% [markdown]
# #### Split data into predictors and target

# %% [markdown]
# The target variable in this problem is the concrete sample strength. Therefore, our predictors will be all the other columns.

# %%
concrete_data_columns = concrete_data.columns

# %%
predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
target = concrete_data['Strength'] # Strength column

# %% [markdown]
# <a id="item2"></a>

# %% [markdown]
# Let's do a quick sanity check of the predictors and the target dataframes.

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %% [markdown]
# Finally, the last step is to normalize the data by substracting the mean and dividing by the standard deviation.

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %% [markdown]
# Let's save the number of predictors to *n_cols* since we will need this number when building our network.

# %%
n_cols = predictors_norm.shape[1] # number of predictors

# %% [markdown]
# <a id="item1"></a>

# %% [markdown]
# ##  Import Keras Packages
#
# ##### Let's import the rest of the packages from the Keras library that we will need to build our regression model.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Input

# %% [markdown]
# ## Build a Neural Network

# %% [markdown]
# Let's define a function that defines our regression model for us so that we can conveniently call it to create our model.

# %%
# define regression model
def regression_model():
    # create model
    model = Sequential()
    model.add(Input(shape=(n_cols,)))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# The above function create a model that has two hidden layers, each of 50 hidden units.

# %% [markdown]
# ## Train and Test the Network

# %% [markdown]
# Let's call the function now to create our model.

# %%
# build the model
model = regression_model()

# %% [markdown]
# Next, we will train and test the model at the same time using the *fit* method. We will leave out 30% of the data for validation and we will train the model for 100 epochs.

# %%
# fit the model
model.fit(predictors_norm, target, validation_split=0.3, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 23/23 - 1s - 49ms/step - loss: 1659.6398 - val_loss: 1159.0883
# Epoch 2/100
# 23/23 - 0s - 8ms/step - loss: 1524.2169 - val_loss: 1040.8717
# Epoch 3/100
# 23/23 - 0s - 7ms/step - loss: 1315.4069 - val_loss: 860.0134
# Epoch 4/100
# 23/23 - 0s - 7ms/step - loss: 1000.1194 - val_loss: 621.5258
# Epoch 5/100
# 23/23 - 0s - 7ms/step - loss: 634.6615 - val_loss: 383.2047
# Epoch 6/100
# 23/23 - 0s - 7ms/step - loss: 358.3380 - val_loss: 243.3317
# Epoch 7/100
# 23/23 - 0s - 7ms/step - loss: 256.4657 - val_loss: 200.5334
# Epoch 8/100
# 23/23 - 0s - 7ms/step - loss: 233.4570 - val_loss: 200.1130
# Epoch 9/100
# 23/23 - 0s - 7ms/step - loss: 220.5550 - val_loss: 191.9232
# Epoch 10/100
# 23/23 - 0s - 6ms/step - loss: 45.6980 - val_loss: 104.7639
# Epoch 74/100
# 23/23 - 0s - 6ms/step - loss: 44.1815 - val_loss: 107.3234
# Epoch 75/100
# 23/23 - 0s - 7ms/step - loss: 43.2065 - val_loss: 107.0823
# Epoch 76/100
# 23/23 - 0s - 6ms/step - loss: 42.6628 - val_loss: 112.3181
# Epoch 77/100
# 23/23 - 0s - 7ms/step - loss: 42.3158 - val_loss: 117.3168
# Epoch 78/100
# 23/23 - 0s - 6ms/step - loss: 41.4902 - val_loss: 113.3274
# Epoch 79/100
# 23/23 - 0s - 7ms/step - loss: 41.0652 - val_loss: 113.1165
# Epoch 80/100
# 23/23 - 0s - 6ms/step - loss: 40.7313 - val_loss: 104.8845
# Epoch 81/100
# 23/23 - 0s - 6ms/step - loss: 40.1981 - val_loss: 111.1553
# Epoch 82/100
# 23/23 - 0s - 6ms/step - loss: 39.7424 - val_loss: 123.1727
# Epoch 83/100
# 23/23 - 0s - 7ms/step - loss: 39.0728 - val_loss: 115.3111
# Epoch 84/100
# 23/23 - 0s - 6ms/step - loss: 38.8662 - val_loss: 111.7583
# Epoch 85/100
# 23/23 - 0s - 6ms/step - loss: 37.1565 - val_loss: 120.4106
# Epoch 86/100
# 23/23 - 0s - 7ms/step - loss: 36.8810 - val_loss: 116.4731
# Epoch 87/100
# 23/23 - 0s - 7ms/step - loss: 36.1630 - val_loss: 119.5771
# Epoch 88/100
# 23/23 - 0s - 6ms/step - loss: 35.8046 - val_loss: 120.8317
# Epoch 89/100
# 23/23 - 0s - 6ms/step - loss: 35.6647 - val_loss: 121.3219
# Epoch 90/100
# 23/23 - 0s - 6ms/step - loss: 35.1268 - val_loss: 122.8046
# Epoch 91/100
# 23/23 - 0s - 6ms/step - loss: 34.9850 - val_loss: 118.4047
# Epoch 92/100
# 23/23 - 0s - 6ms/step - loss: 35.1250 - val_loss: 138.2459
# Epoch 93/100
# 23/23 - 0s - 6ms/step - loss: 35.2372 - val_loss: 127.3840
# Epoch 94/100
# 23/23 - 0s - 7ms/step - loss: 33.9275 - val_loss: 124.6756
# Epoch 95/100
# 23/23 - 0s - 7ms/step - loss: 33.6414 - val_loss: 119.9599
# Epoch 96/100
# 23/23 - 0s - 7ms/step - loss: 33.5003 - val_loss: 126.3612
# Epoch 97/100
# 23/23 - 0s - 7ms/step - loss: 32.8792 - val_loss: 125.6256
# Epoch 98/100
# 23/23 - 0s - 7ms/step - loss: 32.4763 - val_loss: 122.3107
# Epoch 99/100
# 23/23 - 0s - 7ms/step - loss: 32.2279 - val_loss: 132.5293
# Epoch 100/100
# 23/23 - 0s - 10ms/step - loss: 32.0385 - val_loss: 119.7692

# %% [markdown]
# <strong>You can refer to this [link](https://keras.io/models/sequential/) to learn about other functions that you can use for prediction or evaluation.</strong>

# %% [markdown]
# Feel free to vary the following and note what impact each change has on the model's performance:
#
# 1. Increase or decreate number of neurons in hidden layers
# 2. Add more hidden layers
# 3. Increase number of epochs

# %% [markdown]
# <h3>Practice Exercise 1</h3>

# %% [markdown]
# Now using the same dateset,try to recreate regression model featuring five hidden layers, each with 50 nodes and ReLU activation functions, a single output layer, optimized using the Adam optimizer.

# %%
# Write your code here
def adv_regression_model():
    model = Sequential()
    model.add(Input(shape = (n_cols,)))
    model.add(Dense(50, activation = "relu"))
    model.add(Dense(50, activation = "relu"))
    model.add(Dense(50, activation = "relu"))
    model.add(Dense(50, activation = "relu"))
    model.add(Dense(50, activation = "relu"))

    model.add(Dense(1))

    model.compile(optimizer= "adam", loss = "mean_squared_error")
    return model

model = adv_regression_model()
model.fit(predictors_norm, target, validation_split=0.3, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 23/23 - 3s - 147ms/step - loss: 1660.3739 - val_loss: 1140.1429
# Epoch 2/100
# 23/23 - 0s - 17ms/step - loss: 1227.8723 - val_loss: 446.0443
# Epoch 3/100
# 23/23 - 0s - 17ms/step - loss: 366.9207 - val_loss: 194.3279
# Epoch 4/100
# 23/23 - 0s - 17ms/step - loss: 246.9543 - val_loss: 169.7362
# Epoch 5/100
# 23/23 - 0s - 15ms/step - loss: 215.1865 - val_loss: 173.9527
# Epoch 6/100
# 23/23 - 0s - 14ms/step - loss: 195.0217 - val_loss: 172.2877
# Epoch 7/100
# 23/23 - 0s - 14ms/step - loss: 176.8519 - val_loss: 175.2564
# Epoch 8/100
# 23/23 - 0s - 15ms/step - loss: 165.4021 - val_loss: 231.3826
# Epoch 9/100
# 23/23 - 0s - 12ms/step - loss: 158.2576 - val_loss: 220.2724
# Epoch 10/100
# 23/23 - 0s - 13ms/step - loss: 142.4897 - val_loss: 205.4945
# Epoch 11/100
# 23/23 - 0s - 17ms/step - loss: 130.5029 - val_loss: 212.0389
# Epoch 12/100
# 23/23 - 1s - 23ms/step - loss: 119.4387 - val_loss: 214.8212
# Epoch 13/100
# 23/23 - 0s - 10ms/step - loss: 110.2421 - val_loss: 211.1331
# Epoch 14/100
# 23/23 - 0s - 8ms/step - loss: 103.4572 - val_loss: 248.6402
# Epoch 15/100
# 23/23 - 0s - 8ms/step - loss: 93.8501 - val_loss: 260.6762
# Epoch 16/100
# 23/23 - 0s - 8ms/step - loss: 85.5358 - val_loss: 266.0595
# Epoch 17/100
# 23/23 - 0s - 7ms/step - loss: 76.2934 - val_loss: 233.0196
# Epoch 18/100
# 23/23 - 0s - 7ms/step - loss: 68.8785 - val_loss: 200.0012
# Epoch 19/100
# 23/23 - 0s - 8ms/step - loss: 63.9863 - val_loss: 232.9223
# Epoch 20/100
# 23/23 - 0s - 8ms/step - loss: 58.7500 - val_loss: 283.3221
# Epoch 21/100
# 23/23 - 0s - 8ms/step - loss: 57.6439 - val_loss: 226.1921
# Epoch 22/100
# 23/23 - 0s - 8ms/step - loss: 50.0513 - val_loss: 176.4338
# Epoch 23/100
# 23/23 - 0s - 8ms/step - loss: 50.2716 - val_loss: 226.1875
# Epoch 24/100
# 23/23 - 0s - 8ms/step - loss: 46.1909 - val_loss: 200.5779
# Epoch 25/100
# 23/23 - 0s - 8ms/step - loss: 43.6345 - val_loss: 173.8533
# Epoch 26/100
# 23/23 - 0s - 8ms/step - loss: 42.7261 - val_loss: 167.1051
# Epoch 27/100
# Epoch 59/100
# 23/23 - 0s - 9ms/step - loss: 19.1367 - val_loss: 94.9633
# Epoch 60/100
# 23/23 - 0s - 8ms/step - loss: 17.2771 - val_loss: 93.7461
# Epoch 61/100
# 23/23 - 0s - 8ms/step - loss: 17.3420 - val_loss: 88.5087
# Epoch 62/100
# 23/23 - 0s - 8ms/step - loss: 16.7389 - val_loss: 96.5034
# Epoch 63/100
# 23/23 - 0s - 9ms/step - loss: 17.1353 - val_loss: 105.1051
# Epoch 64/100
# 23/23 - 0s - 8ms/step - loss: 16.3656 - val_loss: 85.9871
# Epoch 65/100
# 23/23 - 0s - 7ms/step - loss: 16.3329 - val_loss: 94.8679
# Epoch 66/100
# 23/23 - 0s - 7ms/step - loss: 15.5022 - val_loss: 87.4462
# Epoch 67/100
# 23/23 - 0s - 7ms/step - loss: 16.1171 - val_loss: 77.7496
# Epoch 68/100
# 23/23 - 0s - 8ms/step - loss: 19.1813 - val_loss: 83.7999
# Epoch 69/100
# 23/23 - 0s - 7ms/step - loss: 15.3855 - val_loss: 100.9812
# Epoch 70/100
# 23/23 - 0s - 8ms/step - loss: 15.7572 - val_loss: 95.8001
# Epoch 71/100
# 23/23 - 0s - 8ms/step - loss: 16.4226 - val_loss: 87.2533
# Epoch 72/100
# 23/23 - 0s - 8ms/step - loss: 14.7007 - val_loss: 101.3759
# Epoch 73/100
# 23/23 - 0s - 7ms/step - loss: 14.7067 - val_loss: 85.5072
# Epoch 74/100
# 23/23 - 0s - 8ms/step - loss: 15.1381 - val_loss: 96.1396
# Epoch 75/100
# 23/23 - 0s - 8ms/step - loss: 16.2423 - val_loss: 118.6532
# Epoch 76/100
# 23/23 - 0s - 8ms/step - loss: 19.0439 - val_loss: 97.6439
# Epoch 77/100
# 23/23 - 0s - 8ms/step - loss: 14.9037 - val_loss: 82.8116
# Epoch 78/100
# 23/23 - 0s - 8ms/step - loss: 14.2226 - val_loss: 94.7687
# Epoch 79/100
# 23/23 - 0s - 8ms/step - loss: 14.1394 - val_loss: 88.8054
# Epoch 80/100
# 23/23 - 0s - 8ms/step - loss: 13.6566 - val_loss: 93.1446
# Epoch 81/100
# 23/23 - 0s - 8ms/step - loss: 13.2961 - val_loss: 94.3700
# Epoch 82/100
# 23/23 - 0s - 8ms/step - loss: 13.5304 - val_loss: 84.6843
# Epoch 83/100
# 23/23 - 0s - 8ms/step - loss: 14.7423 - val_loss: 99.0862
# Epoch 84/100
# 23/23 - 0s - 8ms/step - loss: 13.3912 - val_loss: 82.1098
# Epoch 85/100
# 23/23 - 0s - 8ms/step - loss: 13.5849 - val_loss: 115.6670
# Epoch 86/100
# 23/23 - 0s - 8ms/step - loss: 14.2531 - val_loss: 103.1282
# Epoch 87/100
# 23/23 - 0s - 8ms/step - loss: 13.6761 - val_loss: 85.2200
# Epoch 88/100
# 23/23 - 0s - 7ms/step - loss: 16.0495 - val_loss: 95.0226
# Epoch 89/100
# 23/23 - 0s - 7ms/step - loss: 14.0178 - val_loss: 103.5959
# Epoch 90/100
# 23/23 - 0s - 8ms/step - loss: 14.2255 - val_loss: 104.7251
# Epoch 91/100
# 23/23 - 0s - 8ms/step - loss: 15.8117 - val_loss: 93.8207
# Epoch 92/100
# 23/23 - 0s - 7ms/step - loss: 14.5443 - val_loss: 100.6764
# Epoch 93/100
# 23/23 - 0s - 7ms/step - loss: 12.4689 - val_loss: 88.1103
# Epoch 94/100
# 23/23 - 0s - 7ms/step - loss: 12.9643 - val_loss: 96.4440
# Epoch 95/100
# 23/23 - 0s - 9ms/step - loss: 12.7845 - val_loss: 90.6913
# Epoch 96/100
# 23/23 - 0s - 8ms/step - loss: 12.1428 - val_loss: 88.9894
# Epoch 97/100
# 23/23 - 0s - 8ms/step - loss: 12.8016 - val_loss: 90.5487
# Epoch 98/100
# 23/23 - 0s - 8ms/step - loss: 12.4030 - val_loss: 116.0057
# Epoch 99/100
# 23/23 - 0s - 8ms/step - loss: 12.8423 - val_loss: 96.0315
# Epoch 100/100
# 23/23 - 0s - 8ms/step - loss: 12.5841 - val_loss: 97.1207

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- Your answer is below:
# def regression_model():
#     input_colm = predictors_norm.shape[1] # Number of input features
#     # create model
#     model = Sequential()
#     model.add(Input(shape=(input_colm,)))  # Set the number of input features
#     model.add(Dense(50, activation='relu'))
#     model.add(Dense(50, activation='relu'))
#     model.add(Dense(50, activation='relu'))
#     model.add(Dense(50, activation='relu'))
#     model.add(Dense(50, activation='relu'))
#     model.add(Dense(1))  # Output layer
#
#     # compile model
#     model.compile(optimizer='adam', loss='mean_squared_error')
#     return model
#
# -->

# %% [markdown]
# <h3>Practice Exercise 2</h3>

# %% [markdown]
#  Train and evaluate the model simultaneously using the fit() method by reserving 10% of the data for validation and training the model for 100 epochs

# %%
# Write your code here
model = adv_regression_model()
model.fit(predictors_norm, target, validation_split=0.1, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 29/29 - 2s - 68ms/step - loss: 1483.5062 - val_loss: 842.0216
# Epoch 2/100
# 29/29 - 0s - 8ms/step - loss: 601.1519 - val_loss: 270.3463
# Epoch 3/100
# 29/29 - 0s - 9ms/step - loss: 246.7671 - val_loss: 212.8236
# Epoch 4/100
# 29/29 - 0s - 7ms/step - loss: 212.1244 - val_loss: 203.5471
# Epoch 5/100
# 29/29 - 0s - 7ms/step - loss: 186.4959 - val_loss: 188.9022
# Epoch 6/100
# 29/29 - 0s - 7ms/step - loss: 166.9393 - val_loss: 164.6117
# Epoch 7/100
# 29/29 - 0s - 7ms/step - loss: 151.4914 - val_loss: 154.6220
# Epoch 8/100
# 29/29 - 0s - 6ms/step - loss: 128.6310 - val_loss: 129.8137
# Epoch 9/100
# 29/29 - 0s - 7ms/step - loss: 114.6315 - val_loss: 133.6342
# Epoch 10/100
# 29/29 - 0s - 7ms/step - loss: 99.8282 - val_loss: 107.8584
# Epoch 11/100
# 29/29 - 0s - 7ms/step - loss: 86.1151 - val_loss: 114.7756
# Epoch 12/100
# 29/29 - 0s - 7ms/step - loss: 73.9074 - val_loss: 85.1868
# Epoch 13/100
# 29/29 - 0s - 7ms/step - loss: 63.8907 - val_loss: 67.9507
# Epoch 14/100
# 29/29 - 0s - 6ms/step - loss: 56.8373 - val_loss: 64.0778
# Epoch 15/100
# 29/29 - 0s - 7ms/step - loss: 51.7879 - val_loss: 56.0760
# Epoch 16/100
# 29/29 - 0s - 7ms/step - loss: 46.5073 - val_loss: 52.2629
# Epoch 17/100
# 29/29 - 0s - 7ms/step - loss: 43.0135 - val_loss: 40.9514
# Epoch 18/100
# 29/29 - 0s - 6ms/step - loss: 40.3536 - val_loss: 43.4014
# Epoch 19/100
# 29/29 - 0s - 7ms/step - loss: 41.0506 - val_loss: 41.7958
# Epoch 20/100
# 29/29 - 0s - 7ms/step - loss: 36.8333 - val_loss: 35.7033
# Epoch 21/100
# 29/29 - 0s - 7ms/step - loss: 34.4765 - val_loss: 35.9244
# Epoch 22/100
# 29/29 - 0s - 7ms/step - loss: 32.9758 - val_loss: 34.6291
# Epoch 23/100
# 29/29 - 0s - 7ms/step - loss: 32.6278 - val_loss: 29.7092
# Epoch 24/100
# 29/29 - 0s - 7ms/step - loss: 32.4140 - val_loss: 33.5325
# Epoch 25/100
# 29/29 - 0s - 8ms/step - loss: 33.0511 - val_loss: 28.7859
# Epoch 26/100
# 29/29 - 0s - 7ms/step - loss: 29.7063 - val_loss: 26.4761
# Epoch 27/100
# 29/29 - 0s - 7ms/step - loss: 29.6358 - val_loss: 27.5603
# Epoch 28/100
# 29/29 - 0s - 7ms/step - loss: 27.8216 - val_loss: 24.9274
# Epoch 29/100
# 29/29 - 0s - 7ms/step - loss: 27.6848 - val_loss: 24.3451
# Epoch 30/100
# 29/29 - 0s - 7ms/step - loss: 27.2341 - val_loss: 26.2940
# Epoch 31/100
# 29/29 - 0s - 7ms/step - loss: 26.4684 - val_loss: 25.6475
# Epoch 32/100
# 29/29 - 0s - 7ms/step - loss: 25.4986 - val_loss: 25.5772
# Epoch 33/100
# 29/29 - 0s - 6ms/step - loss: 24.6560 - val_loss: 24.0830
# Epoch 34/100
# 29/29 - 0s - 6ms/step - loss: 27.0807 - val_loss: 25.7747
# Epoch 35/100
# 29/29 - 0s - 7ms/step - loss: 25.8682 - val_loss: 24.8515
# Epoch 36/100
# 29/29 - 0s - 7ms/step - loss: 23.0046 - val_loss: 23.2906
# Epoch 37/100
# 29/29 - 0s - 6ms/step - loss: 23.2629 - val_loss: 24.5181
# Epoch 38/100
# 29/29 - 0s - 7ms/step - loss: 21.8169 - val_loss: 22.4663
# Epoch 39/100
# 29/29 - 0s - 6ms/step - loss: 22.9959 - val_loss: 25.5822
# Epoch 40/100
# 29/29 - 0s - 7ms/step - loss: 21.0353 - val_loss: 23.9375
# Epoch 41/100
# 29/29 - 0s - 6ms/step - loss: 21.2089 - val_loss: 23.8564
# Epoch 42/100
# 29/29 - 0s - 7ms/step - loss: 20.2606 - val_loss: 23.4156
# Epoch 43/100
# 29/29 - 0s - 7ms/step - loss: 21.6977 - val_loss: 34.4431
# Epoch 44/100
# 29/29 - 0s - 6ms/step - loss: 20.0929 - val_loss: 26.9805
# Epoch 45/100
# 29/29 - 0s - 7ms/step - loss: 20.6818 - val_loss: 24.3326
# Epoch 46/100
# 29/29 - 0s - 7ms/step - loss: 18.5527 - val_loss: 22.1564
# Epoch 47/100
# 29/29 - 0s - 7ms/step - loss: 19.1247 - val_loss: 21.9100
# Epoch 48/100
# 29/29 - 0s - 6ms/step - loss: 19.1847 - val_loss: 21.5865
# Epoch 49/100
# 29/29 - 0s - 6ms/step - loss: 18.3136 - val_loss: 23.9085
# Epoch 50/100
# 29/29 - 0s - 7ms/step - loss: 18.8667 - val_loss: 22.1965
# Epoch 51/100
# 29/29 - 0s - 7ms/step - loss: 18.1638 - val_loss: 25.5069
# Epoch 52/100
# 29/29 - 0s - 6ms/step - loss: 19.1517 - val_loss: 26.3963
# Epoch 53/100
# 29/29 - 0s - 6ms/step - loss: 18.5261 - val_loss: 21.4511
# Epoch 54/100
# 29/29 - 0s - 7ms/step - loss: 17.3448 - val_loss: 23.0558
# Epoch 55/100
# 29/29 - 0s - 6ms/step - loss: 16.9145 - val_loss: 22.5201
# Epoch 56/100
# 29/29 - 0s - 6ms/step - loss: 15.9951 - val_loss: 24.7564
# Epoch 57/100
# 29/29 - 0s - 6ms/step - loss: 16.5856 - val_loss: 19.3971
# Epoch 58/100
# 29/29 - 0s - 6ms/step - loss: 16.0282 - val_loss: 20.1481
# Epoch 59/100
# 29/29 - 0s - 6ms/step - loss: 16.6178 - val_loss: 20.6138
# Epoch 60/100
# 29/29 - 0s - 6ms/step - loss: 15.2513 - val_loss: 20.1763
# Epoch 61/100
# 29/29 - 0s - 6ms/step - loss: 14.9812 - val_loss: 26.9111
# Epoch 62/100
# 29/29 - 0s - 6ms/step - loss: 15.0763 - val_loss: 23.9646
# Epoch 63/100
# 29/29 - 0s - 7ms/step - loss: 14.8421 - val_loss: 20.1606
# Epoch 64/100
# 29/29 - 0s - 8ms/step - loss: 14.9201 - val_loss: 20.3137
# Epoch 65/100
# 29/29 - 0s - 6ms/step - loss: 14.9571 - val_loss: 21.1247
# Epoch 66/100
# 29/29 - 0s - 7ms/step - loss: 14.8130 - val_loss: 28.8394
# Epoch 67/100
# 29/29 - 0s - 6ms/step - loss: 15.2652 - val_loss: 19.2187
# Epoch 68/100
# 29/29 - 0s - 6ms/step - loss: 15.5520 - val_loss: 18.5177
# Epoch 69/100
# 29/29 - 0s - 7ms/step - loss: 14.3671 - val_loss: 19.4310
# Epoch 70/100
# 29/29 - 0s - 7ms/step - loss: 14.2091 - val_loss: 21.9041
# Epoch 71/100
# 29/29 - 0s - 7ms/step - loss: 14.7986 - val_loss: 18.6635
# Epoch 72/100
# 29/29 - 0s - 7ms/step - loss: 13.7776 - val_loss: 20.7936
# Epoch 73/100
# 29/29 - 0s - 7ms/step - loss: 14.8028 - val_loss: 18.6742
# Epoch 74/100
# 29/29 - 0s - 6ms/step - loss: 14.2003 - val_loss: 18.8429
# Epoch 75/100
# 29/29 - 0s - 6ms/step - loss: 13.6473 - val_loss: 18.2098
# Epoch 76/100
# 29/29 - 0s - 6ms/step - loss: 14.2811 - val_loss: 18.8405
# Epoch 77/100
# 29/29 - 0s - 7ms/step - loss: 14.4247 - val_loss: 21.4339
# Epoch 78/100
# 29/29 - 0s - 6ms/step - loss: 13.7993 - val_loss: 18.1550
# Epoch 79/100
# 29/29 - 0s - 7ms/step - loss: 13.7839 - val_loss: 19.5916
# Epoch 80/100
# 29/29 - 0s - 7ms/step - loss: 13.3432 - val_loss: 21.9675
# Epoch 81/100
# 29/29 - 0s - 7ms/step - loss: 12.7567 - val_loss: 16.8812
# Epoch 82/100
# 29/29 - 0s - 7ms/step - loss: 12.9946 - val_loss: 17.2639
# Epoch 83/100
# 29/29 - 0s - 7ms/step - loss: 13.2316 - val_loss: 18.9177
# Epoch 84/100
# 29/29 - 0s - 6ms/step - loss: 13.7901 - val_loss: 19.7374
# Epoch 85/100
# 29/29 - 0s - 6ms/step - loss: 12.9648 - val_loss: 19.9132
# Epoch 86/100
# 29/29 - 0s - 6ms/step - loss: 12.4712 - val_loss: 16.6970
# Epoch 87/100
# 29/29 - 0s - 6ms/step - loss: 12.0489 - val_loss: 17.1748
# Epoch 88/100
# 29/29 - 0s - 6ms/step - loss: 12.5079 - val_loss: 20.6839
# Epoch 89/100
# 29/29 - 0s - 6ms/step - loss: 13.0861 - val_loss: 17.5304
# Epoch 90/100
# 29/29 - 0s - 6ms/step - loss: 12.5188 - val_loss: 16.4254
# Epoch 91/100
# 29/29 - 0s - 6ms/step - loss: 12.3464 - val_loss: 18.2205
# Epoch 92/100
# 29/29 - 0s - 7ms/step - loss: 12.8070 - val_loss: 19.0066
# Epoch 93/100
# 29/29 - 0s - 7ms/step - loss: 12.2137 - val_loss: 15.7924
# Epoch 94/100
# 29/29 - 0s - 7ms/step - loss: 12.7632 - val_loss: 16.0516
# Epoch 95/100
# 29/29 - 0s - 6ms/step - loss: 12.3801 - val_loss: 21.4605
# Epoch 96/100
# 29/29 - 0s - 6ms/step - loss: 12.7409 - val_loss: 14.5682
# Epoch 97/100
# 29/29 - 0s - 7ms/step - loss: 12.3709 - val_loss: 15.6840
# Epoch 98/100
# 29/29 - 0s - 7ms/step - loss: 11.5464 - val_loss: 21.2912
# Epoch 99/100
# 29/29 - 0s - 7ms/step - loss: 13.0626 - val_loss: 15.2283
# Epoch 100/100
# 29/29 - 0s - 7ms/step - loss: 12.6842 - val_loss: 15.3335

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- Your answer is below:
# # build the model
# model = regression_model()
# model.fit(predictors_norm, target, validation_split=0.1, epochs=100, verbose=2)
#
# -->

# %% [markdown]
# Based on the results, we notice that:
#
# - Adding more hidden layers to the model increases its capacity to learn and represent complex relationships within the data. This allows the model to better identify, as a result, the model becomes more effective at fitting the training data and potentially improving its predictions.
# - By reducing the proportion of data set aside for validation and using a larger portion for training, the model has access to more examples to learn from. This additional training data helps the model improve its understanding of the underlying trends, which can lead to better overall performance.

# %% [markdown]
# ### Thank you for completing this lab!
#
# This notebook was created by [Alex Aklson](https://www.linkedin.com/in/aklson/). I hope you found this lab interesting and educational. Feel free to contact me if you have any questions!

# %% [markdown]
# <!--
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2024-11-20  | 3.0  | Aman  |  Updated the library versions to current |
# | 2020-09-21  | 2.0  | Srishti  |  Migrated Lab to Markdown and added to course repo in GitLab |
#
#
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation. All rights reserved. <h3/>

# %% [markdown]
# ## <h3 align="center"> &#169; IBM Corporation. All rights reserved. <h3/>
